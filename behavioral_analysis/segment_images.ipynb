# %%
import numpy as np
import pandas as pd

import skimage.io
import skimage.filters

import bokeh.io

import bootcamp_utils

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d364f071-2c57-46d4-bcd2-60850d26b3b4">Loading BokehJS ...</span>
#     </div>

# %%
# !ls ../../Dickinson_lab/ant_not_fixed/
# Out:
# ls: ../../Dickinson_lab/ant_not_fixed/3_15_2018/*: No such file or directory

# %%
im = skimage.io.imread('../../Dickinson_lab/ant_not_fixed/3_15_2018/')

# %%
im.shape
# Out:
# (480, 640)

# %%
type(im)
# Out:
# numpy.ndarray

# %%
# !pytest -v ../
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.6.5, pytest-3.5.1, py-1.5.3, pluggy-0.6.0 -- /Users/julianwagner/anaconda3/bin/python
# cachedir: ../.pytest_cache
# rootdir: /Users/julianwagner/git/sceptovideo, inifile:
# plugins: remotedata-0.2.1, openfiles-0.3.0, doctestplus-0.1.3, arraydiff-0.2, hypothesis-3.57.0
# collected 8 items
#
# ../tests/test_segmentation_pipeline.py::test_im_shape PASSED             [ 12%]
# ../tests/test_segmentation_pipeline.py::test_im_data_type_list PASSED    [ 25%]
# ../tests/test_segmentation_pipeline.py::test_im_data_type_string PASSED  [ 37%]
# ../tests/test_segmentation_pipeline.py::test_im_shape_segment PASSED     [ 50%]
# ../tests/test_segmentation_pipeline.py::test_im_data_type_list_segment PASSED [ 62%]
# ../tests/test_segmentation_pipeline.py::test_im_data_type_string_segment PASSED [ 75%]
# ../tests/test_segmentation_pipeline.py::test_provided_function_callable FAILED [ 87%]
# ...

# %%
bokeh.io.show(bootcamp_utils.bokeh_imshow(skimage.filters.threshold_sauvola(image=im, window_size=3, k=)))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="aa187420-2c53-4b1f-a25a-cde1ec153975"></div>
# </div>

# %%
skimage.filters.threshold_sauvola?
# Out:
# Signature: skimage.filters.threshold_sauvola(image, window_size=15, k=0.2, r=None)
# Docstring:
# Applies Sauvola local threshold to an array. Sauvola is a
# modification of Niblack technique.
#
# In the original method a threshold T is calculated for every pixel
# in the image using the following formula:
#
# T = m(x,y) * (1 + k * ((s(x,y) / R) - 1))
#
# where m(x,y) and s(x,y) are the mean and standard deviation of
# pixel (x,y) neighborhood defined by a rectangular window with size w
# times w centered around the pixel. k is a configurable parameter
# that weights the effect of standard deviation.
# R is the maximum standard deviation of a greyscale image.
#
# Parameters
# ----------
# image: (N, M) ndarray
#     Grayscale input image.
# window_size : int, optional
#     Odd size of pixel neighborhood window (e.g. 3, 5, 7...).
# k : float, optional
#     Value of the positive parameter k.
# r : float, optional
#     Value of R, the dynamic range of standard deviation.
# ...
