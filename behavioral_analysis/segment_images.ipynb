# %%
import numpy as np
import pandas as pd

import skimage.io
import skimage.filters

import bokeh.io

import bootcamp_utils

import segmentation

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b8166f6a-042a-4a28-b56a-8debb20a12f9">Loading BokehJS ...</span>
#     </div>

# %%
# !ls ../../Dickinson_lab/ant_not_fixed/
# Out:
# 3_15_2018                        lab_meeting_4_2_2018-Copy1.ipynb
# col.tif                          lab_meeting_4_2_2018.ipynb
# data_info.xlsx

# %%
im = skimage.io.imread('../toy_data/ant_scepto-04092018133745-6089.tiff')
im_bg = skimage.io.imread('../toy_data/col_filed.tiff')

# %%
# !pytest -v ../
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.6.5, pytest-3.5.1, py-1.5.3, pluggy-0.6.0 -- /Users/julianwagner/anaconda3/bin/python
# cachedir: ../.pytest_cache
# rootdir: /Users/julianwagner/git/sceptovideo, inifile:
# plugins: remotedata-0.2.1, openfiles-0.3.0, doctestplus-0.1.3, arraydiff-0.2, hypothesis-3.57.0
# collected 13 items
#
# ../tests/test_segmentation_pipeline.py::test_im_shape PASSED             [  7%]
# ../tests/test_segmentation_pipeline.py::test_im_data_type_list PASSED    [ 15%]
# ../tests/test_segmentation_pipeline.py::test_im_data_type_string PASSED  [ 23%]
# ../tests/test_segmentation_pipeline.py::test_im_shape_segment PASSED     [ 30%]
# ../tests/test_segmentation_pipeline.py::test_im_data_type_list_segment PASSED [ 38%]
# ../tests/test_segmentation_pipeline.py::test_im_data_type_string_segment PASSED [ 46%]
# ../tests/test_segmentation_pipeline.py::test_provided_function_callable PASSED [ 53%]
# ../tests/test_segmentation_pipeline.py::test_provided_function_callable_mat PASSED [ 61%]
# ../tests/test_segmentation_pipeline.py::test_provided_function_returns_correct_shape PASSED [ 69%]
# ../tests/test_segmentation_pipeline.py::test_provided_function_returns_correct_types PASSED [ 76%]
# ../tests/test_segmentation_pipeline.py::test_check_numeric_function PASSED [ 84%]
# ../tests/test_segmentation_pipeline.py::test_bg_subtract_im_type PASSED  [ 92%]
# ../tests/test_segmentation_pipeline.py::test_bg_subtract_im_dims PASSED  [100%]
#
# ========================== 13 passed in 1.67 seconds ===========================

# %%
args = (201,)
im_no_bg = segmentation.bg_subtract(im, im_bg)
im_bw, _, _ = segmentation.segment(im_no_bg, thresh_func=skimage.filters.threshold_otsu, args=args)
bokeh.io.show(bootcamp_utils.bokeh_imshow(im_bw))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d4bde7ae-3d1c-41fe-a8fe-2550eb864a77"></div>
# </div>

# %%
bokeh.io.show(bootcamp_utils.bokeh_imshow(im_no_bg))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1cae9b3a-297a-49a2-8ced-ef9c0998252b"></div>
# </div>

# %%
bokeh.io.show(bootcamp_utils.bokeh_imshow(im_bg))
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="27ea0a59-5bcf-4abd-b4d2-7c60bd0ec2da"></div>
# </div>
